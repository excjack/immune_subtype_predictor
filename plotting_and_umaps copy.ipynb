# %% [markdown]
# # Loading in Data and Setting up the DF

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score, cross_val_predict
import umap
from sklearn.preprocessing import StandardScaler
from lifelines import KaplanMeierFitter

# %%
df = pd.read_csv('gene_set_full_df', sep='\t')
df
# Out:
#      TCGA Participant Barcode Immune Subtype  ENSG00000000003  \
# 0                TCGA-02-2485             C4        79.259265
# 1                TCGA-05-4410             C3        32.748015
# 2                TCGA-05-4424             C2        57.583244
# 3                TCGA-05-4425             C6        27.844002
# 4                TCGA-06-0156             C4        58.939523
# ...                       ...            ...              ...
# 8997             TCGA-ZJ-AAXJ             C2        14.516529
# 8998             TCGA-ZJ-AB0I             C2        27.312392
# 8999             TCGA-ZN-A9VU             C2         7.093416
# 9000             TCGA-ZN-A9VW             C6        12.423349
# 9001             TCGA-ZX-AA5X             C2        29.947485
#
#       ENSG00000000938  ENSG00000002549  ENSG00000002726  ENSG00000002933  \
# 0            6.643151       180.681133         0.090647        82.140709
# 1           10.113990        90.549052        11.822552        78.850117
# 2           14.078790       121.773148        33.468457       157.081749
# 3           11.812519       129.100818         3.831593        89.481817
# 4           10.858051       100.064581         0.154817       184.861346
# ...               ...              ...              ...              ...
# 8997         1.266809         9.294427         1.943475         6.287105
# 8998         1.481216        49.401606         1.285174         5.502288
# 8999         4.913640       214.420303         0.078717        33.854365
# 9000         4.924310       210.633015         0.052957       168.279541
# 9001         8.958138       108.761587         8.370875        47.574001
#
#       ENSG00000004468  ENSG00000005302  ENSG00000006062  ...  ENSG00000265972  \
# 0           28.637477        27.956626         7.839017  ...       118.450700
# 1           15.200869        13.416809         5.517317  ...       811.904960
# 2            7.759850        29.774921         6.494535  ...       278.206262
# 3            2.910681        12.759269         7.397155  ...       307.494101
# 4           10.855256        28.613674        10.896783  ...       200.131620
# ...               ...              ...              ...  ...              ...
# 8997         1.242228         8.690793         3.158169  ...       101.716239
# 8998         0.137200        19.352547         5.706432  ...       137.626600
# 8999        14.356921        10.879736         5.786081  ...       246.533440
# 9000         8.197283        17.094445        25.347770  ...      1338.167620
# 9001         3.698866        22.956586         8.604109  ...       221.768260
#
#       ENSG00000266074  ENSG00000267467  ENSG00000269404  ENSG00000270999  \
# 0            6.169188         0.440010         0.281370              0.0
# 1            5.790760         0.408701         4.601847              0.0
# 2            2.881664         0.366937         1.897250              0.0
# 3            7.002104         0.231589         4.057865              0.0
# 4            6.203811         0.459334         1.801397              0.0
# ...               ...              ...              ...              ...
# 8997         1.174335         0.155927         0.347483              0.0
# 8998         2.748331         0.177743         0.238590              0.0
# 8999         4.076389         0.222226         0.988597              0.0
# 9000         3.660169         0.123595         0.437710              0.0
# 9001         2.622681         0.374434         3.262871              0.0
#
#       ENSG00000271503  ENSG00000273749  ENSG00000274736  ENSG00000275385  \
# 0           10.181587        48.168662         0.341059         0.949180
# 1           89.767850        48.119598         0.775307        35.949800
# 2           46.658927        57.234817         2.949572        81.749300
# 3           63.016300        74.851751         1.175897       144.554500
# 4           34.085660        26.016317         2.358993        27.465400
# ...               ...              ...              ...              ...
# 8997        17.608844        22.626533         0.161633         5.306330
# 8998        39.198254        57.490276         0.325526         9.275790
# 8999        38.483170        77.835267         0.330356         1.086547
# 9000        98.137200        55.939760         0.571140         1.350103
# 9001        56.778850        55.159482         2.454724        20.745110
#
#       ENSG00000276566
# 0            0.000000
# 1            4.710780
# 2            2.082360
# 3            0.372232
# 4            1.868890
# ...               ...
# 8997         0.623718
# 8998         0.000000
# 8999         7.394680
# 9000         0.360392
# 9001         0.429658
#
# [9002 rows x 827 columns]

# %%
df.rename(columns={"Immune Subtype": "immune_subtype"}, inplace=True)

# %%
df.rename(columns={"TCGA Participant Barcode": "tcga_participant_barcode"}, inplace=True)

# %%
df
# Out:
#      immune_subtype  ENSG00000000003  ENSG00000000938  ENSG00000002549  \
# 0                C4        79.259265         6.643151       180.681133
# 1                C3        32.748015        10.113990        90.549052
# 2                C2        57.583244        14.078790       121.773148
# 3                C6        27.844002        11.812519       129.100818
# 4                C4        58.939523        10.858051       100.064581
# ...             ...              ...              ...              ...
# 8997             C2        14.516529         1.266809         9.294427
# 8998             C2        27.312392         1.481216        49.401606
# 8999             C2         7.093416         4.913640       214.420303
# 9000             C6        12.423349         4.924310       210.633015
# 9001             C2        29.947485         8.958138       108.761587
#
#       ENSG00000002726  ENSG00000002933  ENSG00000004468  ENSG00000005302  \
# 0            0.090647        82.140709        28.637477        27.956626
# 1           11.822552        78.850117        15.200869        13.416809
# 2           33.468457       157.081749         7.759850        29.774921
# 3            3.831593        89.481817         2.910681        12.759269
# 4            0.154817       184.861346        10.855256        28.613674
# ...               ...              ...              ...              ...
# 8997         1.943475         6.287105         1.242228         8.690793
# 8998         1.285174         5.502288         0.137200        19.352547
# 8999         0.078717        33.854365        14.356921        10.879736
# 9000         0.052957       168.279541         8.197283        17.094445
# 9001         8.370875        47.574001         3.698866        22.956586
#
#       ENSG00000006062  ENSG00000006638  ...  ENSG00000265972  ENSG00000266074  \
# 0            7.839017         1.503516  ...       118.450700         6.169188
# 1            5.517317         0.684776  ...       811.904960         5.790760
# 2            6.494535         1.722254  ...       278.206262         2.881664
# 3            7.397155         1.424041  ...       307.494101         7.002104
# 4           10.896783         2.613483  ...       200.131620         6.203811
# ...               ...              ...  ...              ...              ...
# 8997         3.158169         0.262520  ...       101.716239         1.174335
# 8998         5.706432         1.506085  ...       137.626600         2.748331
# 8999         5.786081         1.883790  ...       246.533440         4.076389
# 9000        25.347770         4.218940  ...      1338.167620         3.660169
# 9001         8.604109         1.588303  ...       221.768260         2.622681
#
#       ENSG00000267467  ENSG00000269404  ENSG00000270999  ENSG00000271503  \
# 0            0.440010         0.281370              0.0        10.181587
# 1            0.408701         4.601847              0.0        89.767850
# 2            0.366937         1.897250              0.0        46.658927
# 3            0.231589         4.057865              0.0        63.016300
# 4            0.459334         1.801397              0.0        34.085660
# ...               ...              ...              ...              ...
# 8997         0.155927         0.347483              0.0        17.608844
# 8998         0.177743         0.238590              0.0        39.198254
# 8999         0.222226         0.988597              0.0        38.483170
# 9000         0.123595         0.437710              0.0        98.137200
# 9001         0.374434         3.262871              0.0        56.778850
#
#       ENSG00000273749  ENSG00000274736  ENSG00000275385  ENSG00000276566
# 0           48.168662         0.341059         0.949180         0.000000
# 1           48.119598         0.775307        35.949800         4.710780
# 2           57.234817         2.949572        81.749300         2.082360
# 3           74.851751         1.175897       144.554500         0.372232
# 4           26.016317         2.358993        27.465400         1.868890
# ...               ...              ...              ...              ...
# 8997        22.626533         0.161633         5.306330         0.623718
# 8998        57.490276         0.325526         9.275790         0.000000
# 8999        77.835267         0.330356         1.086547         7.394680
# 9000        55.939760         0.571140         1.350103         0.360392
# 9001        55.159482         2.454724        20.745110         0.429658
#
# [9002 rows x 826 columns]

# %%
value_counts = df['immune_subtype'].value_counts()

print(value_counts)
# Out:
# C2    2560
# C1    2381
# C3    2373
# C4    1133
# C5     376
# C6     179
# Name: immune_subtype, dtype: int64

# %% [markdown]
# # Making UMAP for Misclassifyied Points

# %%
# Making the train/test split
df_train, df_test = train_test_split(df, test_size=0.25)
x_train = df_train.drop(columns=["immune_subtype", "tcga_participant_barcode"]).values
y_train = df_train["immune_subtype"].values
xt, xv, yt, yv = train_test_split(x_train, y_train, test_size=0.25)

# Train the random forest classifier on your training data
rfModel = RandomForestClassifier(n_estimators=500, max_depth=200)
rfModel.fit(xt, yt)

# Predict on validation data
predictions = rfModel.predict(xv)

# Calculate overall machine accuracy
accuracy = np.sum(predictions == yv) / len(yv)
print("Machine Accuracy:", accuracy)

# Perform cross-validation on the trained model
cv_scores = cross_val_score(rfModel, x_train, y_train, cv=5)

# Print cross-validation scores
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", np.mean(cv_scores))
# Out:
# Machine Accuracy: 0.8175355450236966
# Cross-Validation Scores: [0.75147929 0.77810651 0.81656805 0.75964392 0.83976261]
# Mean CV Score: 0.7891120748687513

# %%
# Perform cross-validation on the trained model
cv_scores = cross_val_score(rfModel, x_train, y_train, cv=5)

# Print cross-validation scores
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", np.mean(cv_scores))
# Out:
# Cross-Validation Scores: [0.79200592 0.78888889 0.81259259 0.80074074 0.78814815]
# Mean CV Score: 0.7964752583819942

# %%
y_pred = cv_predictions = cross_val_predict(rfModel, x_train, y_train, cv=5)

# %%
y_pred == y_train
# Out:
# array([ True,  True,  True, ...,  True,  True, False])

# %%
perdicted_correctly_mask = y_pred == y_train
not_perdicted_correctly = ~perdicted_correctly_mask
x_train[not_perdicted_correctly]
# Out:
# array([[3.12907399e+01, 2.02055100e+01, 3.69299174e+01, ...,
#         1.33179000e+00, 3.84001600e+02, 0.00000000e+00],
#        [4.80742390e+01, 1.47564830e+01, 7.85405340e+01, ...,
#         6.04909100e-01, 4.46670980e+00, 1.09573000e+00],
#        [2.36808350e+01, 1.74870300e+00, 4.29337693e+01, ...,
#         1.43140000e-01, 1.46970500e+01, 0.00000000e+00],
#        ...,
#        [3.02389700e+01, 9.43808179e-01, 6.39179548e+01, ...,
#         0.00000000e+00, 1.80068600e+00, 0.00000000e+00],
#        [3.54457200e+00, 9.41902000e-01, 4.73393030e+01, ...,
#         2.34790000e-01, 5.25878000e-02, 0.00000000e+00],
#        [6.16742670e+01, 1.67118270e+00, 4.58733250e+01, ...,
#         5.36822000e-01, 8.44965000e+00, 1.22075000e+01]])

# %%
# Making the train/test split
df_train, df_test = train_test_split(df, test_size=0.25)
x_train = df_train.drop(columns=["immune_subtype", "tcga_participant_barcode"]).values
y_train = df_train["immune_subtype"].values
xt, xv, yt, yv = train_test_split(x_train, y_train, test_size=0.25)

# Train the random forest classifier on your training data
rfModel = RandomForestClassifier(n_estimators=500, max_depth=200)
rfModel.fit(xt, yt)

# Predict on validation data
predictions = rfModbel.predict(xv)

# Calculate overall machine accuracy
accuracy = np.sum(predictions == yv) / len(yv)
print("Machine Accuracy:", accuracy)

#figsize
plt.figure(figsize=(15, 10))

# Apply UMAP on your data
umap_embedding = umap.UMAP(n_neighbors=5, min_dist=0.3, random_state=11).fit_transform(xv)

# Create a color palette for correctly and incorrectly classified points
color_palette = sns.color_palette("Set1", n_colors=2)  # Two colors: Correct and Incorrect

# Map each class to a color in the palette
class_to_color = {True: color_palette[1], False: color_palette[0]}  # True for Correct, False for Incorrect

# Plot UMAP embeddings with different colors for misclassified points
plt.scatter(
    umap_embedding[:, 0],
    umap_embedding[:, 1],
    s = 4, c=[class_to_color[prediction == actual] for prediction, actual in zip(predictions, yv)]
    )

plt.gca().set_aspect('equal', 'datalim')
plt.title('Misclassified Points', fontsize=16)
plt.legend(["Correct", "Incorrect"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Making the train/test split
#       2 df_train, df_test = train_test_split(df, test_size=0.25)
# ----> 3 x_train = df_train.drop(columns=["immune_subtype", "tcga_participant_barcode"]).values
#       4 y_train = df_train["immune_subtype"].values
#       5 xt, xv, yt, yv = train_test_split(x_train, y_train, test_size=0.25)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['tcga_participant_barcode'] not found in axis"

# %%
df = df.drop(columns='tcga_participant_barcode')
df
# Out:
#      immune_subtype  ENSG00000000003  ENSG00000000938  ENSG00000002549  \
# 0                C4        79.259265         6.643151       180.681133
# 1                C3        32.748015        10.113990        90.549052
# 2                C2        57.583244        14.078790       121.773148
# 3                C6        27.844002        11.812519       129.100818
# 4                C4        58.939523        10.858051       100.064581
# ...             ...              ...              ...              ...
# 8997             C2        14.516529         1.266809         9.294427
# 8998             C2        27.312392         1.481216        49.401606
# 8999             C2         7.093416         4.913640       214.420303
# 9000             C6        12.423349         4.924310       210.633015
# 9001             C2        29.947485         8.958138       108.761587
#
#       ENSG00000002726  ENSG00000002933  ENSG00000004468  ENSG00000005302  \
# 0            0.090647        82.140709        28.637477        27.956626
# 1           11.822552        78.850117        15.200869        13.416809
# 2           33.468457       157.081749         7.759850        29.774921
# 3            3.831593        89.481817         2.910681        12.759269
# 4            0.154817       184.861346        10.855256        28.613674
# ...               ...              ...              ...              ...
# 8997         1.943475         6.287105         1.242228         8.690793
# 8998         1.285174         5.502288         0.137200        19.352547
# 8999         0.078717        33.854365        14.356921        10.879736
# 9000         0.052957       168.279541         8.197283        17.094445
# 9001         8.370875        47.574001         3.698866        22.956586
#
#       ENSG00000006062  ENSG00000006638  ...  ENSG00000265972  ENSG00000266074  \
# 0            7.839017         1.503516  ...       118.450700         6.169188
# 1            5.517317         0.684776  ...       811.904960         5.790760
# 2            6.494535         1.722254  ...       278.206262         2.881664
# 3            7.397155         1.424041  ...       307.494101         7.002104
# 4           10.896783         2.613483  ...       200.131620         6.203811
# ...               ...              ...  ...              ...              ...
# 8997         3.158169         0.262520  ...       101.716239         1.174335
# 8998         5.706432         1.506085  ...       137.626600         2.748331
# 8999         5.786081         1.883790  ...       246.533440         4.076389
# 9000        25.347770         4.218940  ...      1338.167620         3.660169
# 9001         8.604109         1.588303  ...       221.768260         2.622681
#
#       ENSG00000267467  ENSG00000269404  ENSG00000270999  ENSG00000271503  \
# 0            0.440010         0.281370              0.0        10.181587
# 1            0.408701         4.601847              0.0        89.767850
# 2            0.366937         1.897250              0.0        46.658927
# 3            0.231589         4.057865              0.0        63.016300
# 4            0.459334         1.801397              0.0        34.085660
# ...               ...              ...              ...              ...
# 8997         0.155927         0.347483              0.0        17.608844
# 8998         0.177743         0.238590              0.0        39.198254
# 8999         0.222226         0.988597              0.0        38.483170
# 9000         0.123595         0.437710              0.0        98.137200
# 9001         0.374434         3.262871              0.0        56.778850
#
#       ENSG00000273749  ENSG00000274736  ENSG00000275385  ENSG00000276566
# 0           48.168662         0.341059         0.949180         0.000000
# 1           48.119598         0.775307        35.949800         4.710780
# 2           57.234817         2.949572        81.749300         2.082360
# 3           74.851751         1.175897       144.554500         0.372232
# 4           26.016317         2.358993        27.465400         1.868890
# ...               ...              ...              ...              ...
# 8997        22.626533         0.161633         5.306330         0.623718
# 8998        57.490276         0.325526         9.275790         0.000000
# 8999        77.835267         0.330356         1.086547         7.394680
# 9000        55.939760         0.571140         1.350103         0.360392
# 9001        55.159482         2.454724        20.745110         0.429658
#
# [9002 rows x 826 columns]

# %%
# Making the train/test split
df_train, df_test = train_test_split(df, test_size=0.25)
x_train = df_train.drop(columns=["immune_subtype"]).values
y_train = df_train["immune_subtype"].values
xt, xv, yt, yv = train_test_split(x_train, y_train, test_size=0.25)

# Train the random forest classifier on your training data
rfModel = RandomForestClassifier(n_estimators=500, max_depth=200)
rfModel.fit(xt, yt)

# Predict on validation data
predictions = rfModel.predict(xv)

# Calculate overall machine accuracy
accuracy = np.sum(predictions == yv) / len(yv)
print("Machine Accuracy:", accuracy)

# Apply UMAP on your data
umap_embedding = umap.UMAP(n_neighbors=5, min_dist=0.3, random_state=7).fit_transform(xv)

# Create a color palette for correctly and incorrectly classified points
color_palette = sns.color_palette("Set1", n_colors=2)  # Two colors: Correct and Incorrect

# Map each class to a color in the palette
class_to_color = {True: color_palette[1], False: color_palette[0]}  # True for Correct, False for Incorrect

# Set the figure size
plt.figure(figsize=(15, 10))

# Create scatter plot objects for each class
correct_points = plt.scatter(
    umap_embedding[yv == predictions, 0],
    umap_embedding[yv == predictions, 1],
    s=4,
    c=class_to_color[True],
    label='Correct'
)

incorrect_points = plt.scatter(
    umap_embedding[yv != predictions, 0],
    umap_embedding[yv != predictions, 1],
    s=4,
    c=class_to_color[False],
    label='Incorrect'
)

plt.gca().set_aspect('equal', 'datalim')
plt.title('Misclassified Points', fontsize=16)

# Add legend with custom handles
plt.legend(handles=[correct_points, incorrect_points])

plt.show()
# Out:
# Machine Accuracy: 0.7861374407582938
# /var/folders/f2/s93pnt0d3hxdjkhfxs6gb1l1rb54ft/T/ipykernel_14995/1714479393.py:31: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   correct_points = plt.scatter(
# /var/folders/f2/s93pnt0d3hxdjkhfxs6gb1l1rb54ft/T/ipykernel_14995/1714479393.py:39: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   incorrect_points = plt.scatter(

# %%
# Apply UMAP on your data
umap_embedding = umap.UMAP(n_neighbors=5, min_dist=0.3, random_state=7).fit_transform(xv)

# Create a dictionary to map unique immune_subtype values to colors
unique_subtypes = np.unique(yv)
color_palette = sns.color_palette("tab10", n_colors=len(unique_subtypes))
subtype_to_color = dict(zip(unique_subtypes, color_palette))

# Set the figure size
plt.figure(figsize=(15, 10))

# Create scatter plot objects for each immune_subtype
scatter_handles = []
for subtype, color in subtype_to_color.items():
    subset_indices = (yv == subtype)
    scatter_handle = plt.scatter(
        umap_embedding[subset_indices, 0],
        umap_embedding[subset_indices, 1],
        s=4,
        c=[color],
        label=subtype
    )
    scatter_handles.append(scatter_handle)

plt.gca().set_aspect('equal', 'datalim')
plt.title('Correct Mapping', fontsize=16)

# Add legend with custom handles for each immune_subtype
plt.legend(handles=scatter_handles)

plt.show()

# %%
print(misclassified_indices)
print(misclassified_samples)
# Out:
# [False False False ... False False False]
# [[48.236217   1.7480388 48.566702  ...  0.         3.48672    0.       ]
#  [11.236189   2.176721  49.920966  ...  0.230057  30.7236     0.153196 ]
#  [16.477333  12.05723   97.20623   ...  1.896848  38.4101     0.       ]
#  ...
#  [24.29322    2.675615  95.024493  ...  0.2769707  4.62799    0.165192 ]
#  [81.959654   0.9845503 99.535197  ...  0.513831   1.479555   0.       ]
#  [ 6.399854   3.842963  72.478901  ...  3.113788   1.439876   3.89749  ]]

# %%
# Calculate misclassified points
misclassified_indices = (predictions != yv)

# Get the misclassified points
misclassified_samples = xv[misclassified_indices]
misclassified_true_labels = yv[misclassified_indices]
misclassified_predicted_labels = predictions[misclassified_indices]

# Calculate counts of each classification in the validation set
unique_classifications, classification_counts = np.unique(yv, return_counts=True)

# Display misclassified samples and counts for each classification
for classification, misclassified_count, total_classification_count in zip(unique_classifications, classification_counts, classification_counts):
    misclassified_for_classification = (misclassified_true_labels == classification)
    
    print(f"Classification: {classification}")
    print(f"Number of Misclassified Points: {misclassified_count}")
    print(f"Total Number of Points: {total_classification_count}")
    print(f"Misclassified Samples:")
    print(misclassified_samples[misclassified_for_classification])
    print("="*30)
# Out:
# Classification: C1
# Number of Misclassified Points: 448
# Total Number of Points: 448
# Misclassified Samples:
# [[1.64773330e+01 1.20572300e+01 9.72062300e+01 ... 1.89684800e+00
#   3.84101000e+01 0.00000000e+00]
#  [4.37868700e+01 3.73282660e+00 5.10574687e+01 ... 5.12891300e-01
#   1.45553900e+01 4.12351000e+02]
#  [4.24451431e+01 4.89123350e+00 2.34334190e+01 ... 6.81589000e-02
#   6.46598000e-01 0.00000000e+00]
#  ...
#  [2.31047660e+01 2.10746248e+01 6.29485050e+01 ... 5.67058900e+00
#   7.64941000e+01 2.17476000e+01]
#  [2.88065240e+01 2.40646600e+00 8.45095198e+01 ... 3.52207000e-01
#   7.45488000e+00 5.08914000e+00]
#  [2.42911130e+01 1.96845000e+00 6.57068060e+01 ... 3.76872000e-01
#   1.68418000e+01 1.97095000e-01]]
# ==============================
# Classification: C2
# Number of Misclassified Points: 472
# Total Number of Points: 472
# Misclassified Samples:
# [[1.56566810e+01 4.83737664e-01 1.94823440e+01 ... 6.52709000e-02
#   1.96899300e-01 4.92235000e-02]
#  [1.88306950e+01 1.65129300e+00 4.43075697e+01 ... 2.93230600e-01
#   1.03947000e+01 0.00000000e+00]
#  [3.18482192e+01 5.27754100e+00 3.81389106e+01 ... 1.14101000e+00
#   6.65756000e+01 0.00000000e+00]
#  ...
#  [3.86177380e+01 4.05570000e-01 5.77756921e+01 ... 8.28288000e-02
#   9.03893000e-02 2.91928000e-01]
#  [1.47305357e+01 3.45538501e+00 3.24717182e+01 ... 5.70468000e-01
#   4.75352100e+00 1.35827000e+01]
#  [1.41125772e+01 9.86916000e-01 5.32680160e+01 ... 9.19891000e-02
#   7.50298000e+00 0.00000000e+00]]
# ==============================
# Classification: C3
# Number of Misclassified Points: 457
# Total Number of Points: 457
# Misclassified Samples:
# [[1.12361890e+01 2.17672100e+00 4.99209660e+01 ... 2.30057000e-01
#   3.07236000e+01 1.53196000e-01]
#  [1.25746920e+01 2.82026100e+00 4.01785550e+01 ... 1.73677000e-01
#   5.73757000e+00 0.00000000e+00]
#  [3.27393900e+01 1.06487300e+00 4.89688091e+01 ... 6.09513000e-01
#   5.50852000e-02 5.98009000e-01]
#  ...
#  [3.05545700e+01 4.04993600e+00 3.35939370e+01 ... 1.96104000e-01
#   5.61908000e-01 0.00000000e+00]
#  [5.84320140e+01 1.55302200e+00 2.55861280e+01 ... 0.00000000e+00
#   7.45795000e-02 0.00000000e+00]
#  [8.19596540e+01 9.84550300e-01 9.95351970e+01 ... 5.13831000e-01
#   1.47955500e+00 0.00000000e+00]]
# ==============================
# Classification: C4
# Number of Misclassified Points: 227
# Total Number of Points: 227
# Misclassified Samples:
# [[48.236217    1.7480388  48.566702   ...  0.          3.48672
#    0.        ]
#  [16.785163    1.7699456  70.036699   ...  0.          9.11494
#    0.        ]
#  [15.957962    1.13391659 74.802258   ...  0.339778    1.191726
#    0.        ]
#  ...
#  [61.12919     0.372564   39.972282   ...  0.311926    1.366214
#    0.42481   ]
#  [24.29322     2.675615   95.024493   ...  0.2769707   4.62799
#    0.165192  ]
#  [ 6.399854    3.842963   72.478901   ...  3.113788    1.439876
#    3.89749   ]]
# ==============================
# Classification: C5
# Number of Misclassified Points: 53
# Total Number of Points: 53
# Misclassified Samples:
# [[1.82771640e+01 1.00894753e+00 4.65872653e+01 ... 3.32519000e-02
#   9.97154000e+00 0.00000000e+00]
#  [1.61242300e+01 8.96129600e-01 4.70566158e+01 ... 2.90633000e-02
#   0.00000000e+00 0.00000000e+00]
#  [1.50685400e+00 4.97849800e-01 1.21595270e+01 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [2.33869980e+01 4.82738240e+00 6.06044110e+01 ... 2.65334500e-01
#   3.38057300e-01 1.41288000e-01]
#  [2.76931360e+01 1.12325090e+00 5.54625780e+01 ... 0.00000000e+00
#   1.48995300e+00 1.52198000e-01]
#  [8.36883300e+00 1.21249610e+01 8.43477220e+01 ... 1.60313000e-01
#   4.09818000e-02 0.00000000e+00]]
# ==============================
# Classification: C6
# Number of Misclassified Points: 31
# Total Number of Points: 31
# Misclassified Samples:
# [[7.74125480e+01 8.89935310e+00 6.16581455e+01 ... 1.66148450e+00
#   8.19100000e+01 3.71902000e+00]
#  [1.21880563e+02 2.48632500e+00 1.16322830e+02 ... 1.13590000e+00
#   1.19721700e+01 0.00000000e+00]
#  [4.45538550e+00 1.30883970e+00 6.99256950e+01 ... 4.63651000e-02
#   1.07691500e+00 3.47387000e-01]
#  ...
#  [1.88954185e+01 6.27691500e+00 1.31216871e+02 ... 2.29094800e+00
#   7.18148000e+01 1.16568000e-01]
#  [3.97716200e+00 1.01075000e+00 3.48643700e+00 ... 1.03542000e-01
#   1.77367000e+00 2.04603000e-01]
#  [3.70629447e+01 7.21256700e+00 1.00162764e+02 ... 1.14802600e+00
#   3.67709800e+00 0.00000000e+00]]
# ==============================

# %%
# Perform cross-validation on the trained model
cv_scores = cross_val_score(rfModel, xv, yv, cv=5)

#figsize
plt.figure(figsize=(15, 10))

# Apply UMAP on your data
umap_embedding = umap.UMAP(n_neighbors=5, min_dist=0.3).fit_transform(xv)

# Create a color palette for correctly and incorrectly classified points
color_palette = sns.color_palette(['blue', 'red'])  # Two colors: Correct and Incorrect

# Map each class to a color in the palette
class_to_color = {True: color_palette[0], False: color_palette[1]}  # True for Correct, False for Incorrect

# Plot UMAP embeddings with different colors for misclassified points
plt.scatter(
    umap_embedding[:, 0],
    umap_embedding[:, 1],
    s = 4, c=[class_to_color[prediction == actual] for prediction, actual in zip(predictions, yv)]
)

plt.gca().set_aspect('equal', 'datalim')
plt.title('Misclassified Points', fontsize=16)
plt.legend()
plt.show()

# Print cross-validation scores
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", np.mean(cv_scores))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Cross-Validation Scores: [0.79289941 0.77218935 0.77514793 0.78635015 0.73590504]
# Mean CV Score: 0.7724983758537742

# %%
# Perform cross-validation on the trained model
cv_scores = cross_val_score(rfModel, xv, yv, cv=5)

#figsize
plt.figure(figsize=(15, 10))

# Apply UMAP on your data
umap_embedding = umap.UMAP(n_neighbors=5, min_dist=0.3).fit_transform(xv)

# Create a color palette for correctly and incorrectly classified points
color_palette = sns.color_palette("Set1", n_colors=2)  # Two colors: Correct and Incorrect

# Map each class to a color in the palette
class_to_color = {True: color_palette[1], False: color_palette[0]}  # True for Correct, False for Incorrect

# Plot UMAP embeddings with different colors for misclassified points
plt.scatter(
    umap_embedding[:, 0],
    umap_embedding[:, 1],
    s = 4, c=[class_to_color[prediction == actual] for prediction, actual in zip(predictions, yv)]
    )

plt.gca().set_aspect('equal', 'datalim')
plt.title('Misclassified Points', fontsize=16)
plt.show()

# Print cross-validation scores
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", np.mean(cv_scores))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Cross-Validation Scores: [0.79289941 0.76331361 0.77810651 0.76854599 0.78338279]
# Mean CV Score: 0.7772496620020017

# %%
# Perform cross-validation on the trained model
cv_scores = cross_val_score(rfModel, xv, yv, cv=5)

# Set up the color palette with only grey and red
color_palette = sns.color_palette("Set1", n_colors=2)

# Apply UMAP on your data
umap_embedding = umap.UMAP(n_neighbors=5, min_dist=0.3).fit_transform(xv)

# Map each class to a color in the palette
class_to_color = {True: color_palette[1], False: color_palette[0]}  # True for Correct, False for Incorrect

# Set a smaller figure size
plt.figure(figsize=(15, 10))  # Adjust the dimensions as needed

# Plot UMAP embeddings with grey and red colors for misclassified points
plt.scatter(
    umap_embedding[:, 0],
    umap_embedding[:, 1],
    s=4,
    c=[class_to_color[prediction == actual] for prediction, actual in zip(predictions, yv)],
    label=['Misclassified' if prediction != actual else 'Correct' for prediction, actual in zip(predictions, yv)]
)

# Set the aspect and other plot settings
plt.gca().set_aspect('equal', 'datalim')
plt.title('Misclassified Points', fontsize=16)

# Add legend with custom labels
plt.legend()

# Display the plot
plt.show()

# Print cross-validation scores
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", np.mean(cv_scores))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~/anaconda3/lib/python3.10/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2362, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2358 try:
#    2359     # _get_renderer may change the figure dpi (as vector formats
#    2360     # force the figure dpi to 72), so we need to set it again here.
#    2361     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362         result = print_method(
#    2363             filename,
#    2364             facecolor=facecolor,
#    2365             edgecolor=edgecolor,
#    2366             orientation=orientation,
#    2367             bbox_inches_restore=_bbox_inches_restore,
#    2368             **kwargs)
#    2369 finally:
#    2370     if bbox_inches and restore_bbox:
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backend_bases.py:2228, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2224     optional_kws = {  # Passed by print_figure for other renderers.
#    2225         "dpi", "facecolor", "edgecolor", "orientation",
#    2226         "bbox_inches_restore"}
#    2227     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230 else:  # Let third-parties do as they see fit.
#    2231     print_method = meth
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)
#     507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:457, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     452 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     453     """
#     454     Draw the canvas, then save it using `.image.imsave` (to which
#     455     *pil_kwargs* and *metadata* are forwarded).
#     456     """
# --> 457     FigureCanvasAgg.draw(self)
#     458     mpl.image.imsave(
#     459         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:394, in FigureCanvasAgg.draw(self)
#     392 def draw(self):
#     393     # docstring inherited
# --> 394     self.renderer = self.get_renderer()
#     395     self.renderer.clear()
#     396     # Acquire a lock on the shared font cache.
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:384, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     379 @functools.wraps(func)
#     380 def wrapper(*inner_args, **inner_kwargs):
#     381     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     382         # Early return in the simple, non-deprecated case (much faster than
#     383         # calling bind()).
# --> 384         return func(*inner_args, **inner_kwargs)
#     385     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     386     if is_varargs and arguments.get(name):
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:411, in FigureCanvasAgg.get_renderer(self, cleared)
#     409 reuse_renderer = (self._lastKey == key)
#     410 if not reuse_renderer:
# --> 411     self.renderer = RendererAgg(w, h, self.figure.dpi)
#     412     self._lastKey = key
#     413 elif cleared:
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:84, in RendererAgg.__init__(self, width, height, dpi)
#      82 self.width = width
#      83 self.height = height
# ---> 84 self._renderer = _RendererAgg(int(width), int(height), dpi)
#      85 self._filter_renderers = []
#      87 self._update_methods()
#
# ValueError: Image size of 125931x840 pixels is too large. It must be less than 2^16 in each direction.
# Cross-Validation Scores: [0.79585799 0.76035503 0.77218935 0.79525223 0.72997033]
# Mean CV Score: 0.7707249837585377

# %% [markdown]
# # Making the U-Map (not sorted)

# %%
#isolates the signfigant values that will be reduced
x = df.drop(['tcga_participant_barcode', 'immune_subtype'], axis=1)
#seperates the y-value and puts it aside for use later
y = df['immune_subtype']

# %%
#making the model
umap_model = umap.UMAP(n_components=2)
#running the x(values) throught to be reduced
embedding = umap_model.fit_transform(x)
#seeing reduced version
embedding
# Out:
# array([[14.055931 ,  3.4260514],
#        [ 4.1822305,  1.4113327],
#        [ 7.2627754,  2.5849764],
#        ...,
#        [ 7.699954 , -0.6994528],
#        [ 6.8388314, -1.382364 ],
#        [ 8.644294 ,  2.0865276]], dtype=float32)

# %%
#setting plot size
plt.figure(figsize=(15, 10))
#setting color palate and having it change based on the unque y values
color_palette = sns.color_palette("Set1", n_colors=len(y.unique()))
color_mapping = {species: color for color, species in enumerate(y.unique())}
colors = [color_palette[color_mapping[species]] for species in y]
plt.scatter(embedding[:, 0], embedding[:, 1], c=colors, s=2)

# Adding a legend
legend_labels = y.unique()
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', label=label, markersize=15, markerfacecolor=color)
                  for label, color in zip(legend_labels, color_palette)]
plt.legend(handles=legend_handles, title="Immune Subtype")

plt.title('UMAP projection', fontsize=16)
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.show()

# %% [markdown]
# # Sorted DF by immune subtype

# %%
# Define the desired order
desired_order = ["C1", "C2", "C3", "C4", "C5", "C6"]

# Sort the DataFrame based on the 'Column_to_sort' column using the desired order
df_sorted = df[df['immune_subtype'].isin(desired_order)].sort_values(by=['immune_subtype'], key=lambda col: col.map({val: idx for idx, val in enumerate(desired_order)}))

# Print the sorted DataFrame
df_sorted
# Out:
#      immune_subtype  ENSG00000000003  ENSG00000000938  ENSG00000002549  \
# 1921             C1        11.594583         4.406692        67.946749
# 5936             C1        90.922840         2.688882       110.052623
# 5931             C1        17.182080         0.554300        40.694352
# 5928             C1        39.801995         2.825573        54.177553
# 5926             C1        63.173188         4.577430        42.635002
# ...             ...              ...              ...              ...
# 4826             C6         3.706540        10.106416       158.210769
# 4831             C6        41.825828         2.552468       116.600487
# 8648             C6        25.487009         6.408825        48.545101
# 2263             C6        17.579842        18.383990        58.624171
# 2816             C6        20.272618         4.609404        63.443719
#
#       ENSG00000002726  ENSG00000002933  ENSG00000004468  ENSG00000005302  \
# 1921         0.465439        84.156429         0.760922        18.264237
# 5936        81.505346       483.355557         1.412301        20.683607
# 5931        18.391933        15.557973         0.225194         7.527834
# 5928         4.938320        39.437935         0.753132        12.103748
# 5926        46.455515        10.324238         5.759002        16.541371
# ...               ...              ...              ...              ...
# 4826         0.632195        51.345266        21.378058        31.268695
# 4831         0.214475        67.465646         1.279970        22.413583
# 8648         0.904519        77.909946         0.551660        26.351628
# 2263       110.464455       587.231955         1.007275        12.436026
# 2816       215.910697       159.230684         3.827641        18.939639
#
#       ENSG00000006062  ENSG00000006638  ...  ENSG00000265972  ENSG00000266074  \
# 1921        13.746092         6.160153  ...       286.787967         9.898479
# 5936         7.836823         1.364553  ...        81.001330         2.701847
# 5931        28.537830         1.546921  ...       147.497600        21.098441
# 5928         3.709542         2.732352  ...       135.135483         1.009128
# 5926         7.939135         1.824480  ...       182.132730         1.582215
# ...               ...              ...  ...              ...              ...
# 4826         8.503381         0.994787  ...       215.364580         1.324405
# 4831         5.803060         1.778630  ...       412.695200         2.024873
# 8648         5.753635         1.211891  ...       203.050936         3.216982
# 2263         8.946199         1.480787  ...       715.606920         4.060936
# 2816         9.937944         1.562338  ...       268.927500         3.737674
#
#       ENSG00000267467  ENSG00000269404  ENSG00000270999  ENSG00000271503  \
# 1921         0.092957         3.082746         0.000000        40.135650
# 5936         0.637189         0.778437         0.160316         9.836573
# 5931         0.000000         0.627473         0.000000         7.870030
# 5928         0.000000         0.594432         0.000000        20.859734
# 5926         0.000000         0.606945         0.000000        17.729025
# ...               ...              ...              ...              ...
# 4826         0.173291         7.536303         0.298645       100.529080
# 4831         0.624021         0.795011         0.648174        22.903493
# 8648         0.268924         0.861924         0.000000        15.121620
# 2263         0.465955         0.895588         0.196406        15.143496
# 2816         0.069003         8.000608         0.892366        46.112792
#
#       ENSG00000273749  ENSG00000274736  ENSG00000275385  ENSG00000276566
# 1921        41.826091         0.399227         1.928391          0.00000
# 5936        45.617194         0.305265        12.951730          5.46751
# 5931        66.468640         0.000000         2.625727          0.00000
# 5928        57.244140         0.092686        11.306840          0.00000
# 5926        63.327205         1.054340         0.000000          0.00000
# ...               ...              ...              ...              ...
# 4826        57.968099         0.657303        15.845610         26.59740
# 4831        44.155038         0.183690         0.772245         15.32030
# 8648        76.523070         0.084260         9.001380          0.00000
# 2263        64.205272         2.138957        35.317700          0.00000
# 2816        49.103766         2.344436        43.518500         22.05730
#
# [9002 rows x 826 columns]

# %%
#isolates the signfigant values that will be reduced
#x = df_sorted.drop(['tcga_participant_barcode', 'immune_subtype'], axis=1)
x = df_sorted.drop(['immune_subtype'], axis=1)
#seperates the y-value and puts it aside for use later
y = df_sorted['immune_subtype']

# %%
#making the model
umap_model = umap.UMAP(n_components=2, random_state=11)
#running the x(values) throught to be reduced
embedding = umap_model.fit_transform(x)
#seeing reduced version
embedding
# Out:
# array([[8.017926  , 4.1361084 ],
#        [7.9422865 , 5.861159  ],
#        [9.526242  , 8.519604  ],
#        ...,
#        [6.682146  , 0.32770327],
#        [7.7729526 , 3.3525255 ],
#        [5.2072067 , 3.351073  ]], dtype=float32)

# %%
#setting plot size
plt.figure(figsize=(15, 10))
#setting color palate and having it change based on the unque y values
color_palette = sns.color_palette("tab10", n_colors=len(y.unique()))
color_mapping = {species: color for color, species in enumerate(y.unique())}
colors = [color_palette[color_mapping[species]] for species in y]
plt.scatter(embedding[:, 0], embedding[:, 1], c=colors, s=2)

# Adding a legend
legend_labels = y.unique()
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', label=label, markersize=15, markerfacecolor=color)
                  for label, color in zip(legend_labels, color_palette)]
plt.legend(handles=legend_handles, title="Immune Subtype")

plt.title('Immune Subtype UMAP Projection', fontsize=16)
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.show()

# %% [markdown]
# # Making another Data Set

# %%
from sklearn.metrics import accuracy_score

# Features and target
X = df_sorted.drop(columns=["immune_subtype"])
y = df_sorted["immune_subtype"]

# Initialize the model
model = RandomForestClassifier(n_estimators=500, max_depth=200)

# Perform cross-validation predictions
cv_predictions = cross_val_predict(model, X, y, cv=5)

# Calculate accuracy based on cross-validation
accuracy = accuracy_score(y, cv_predictions)
print("Cross-Validation Accuracy:", accuracy)

# Add a new column to the DataFrame to indicate correct predictions
df_sorted["correct_prediction"] = df_sorted["immune_subtype"] == cv_predictions

# Display the DataFrame with the new column
df_sorted
# Out:
# Cross-Validation Accuracy: 0.7976005332148411
#      immune_subtype  ENSG00000000003  ENSG00000000938  ENSG00000002549  \
# 1921             C1        11.594583         4.406692        67.946749
# 5936             C1        90.922840         2.688882       110.052623
# 5931             C1        17.182080         0.554300        40.694352
# 5928             C1        39.801995         2.825573        54.177553
# 5926             C1        63.173188         4.577430        42.635002
# ...             ...              ...              ...              ...
# 4826             C6         3.706540        10.106416       158.210769
# 4831             C6        41.825828         2.552468       116.600487
# 8648             C6        25.487009         6.408825        48.545101
# 2263             C6        17.579842        18.383990        58.624171
# 2816             C6        20.272618         4.609404        63.443719
#
#       ENSG00000002726  ENSG00000002933  ENSG00000004468  ENSG00000005302  \
# 1921         0.465439        84.156429         0.760922        18.264237
# 5936        81.505346       483.355557         1.412301        20.683607
# 5931        18.391933        15.557973         0.225194         7.527834
# 5928         4.938320        39.437935         0.753132        12.103748
# 5926        46.455515        10.324238         5.759002        16.541371
# ...               ...              ...              ...              ...
# 4826         0.632195        51.345266        21.378058        31.268695
# 4831         0.214475        67.465646         1.279970        22.413583
# 8648         0.904519        77.909946         0.551660        26.351628
# 2263       110.464455       587.231955         1.007275        12.436026
# 2816       215.910697       159.230684         3.827641        18.939639
#
#       ENSG00000006062  ENSG00000006638  ...  ENSG00000266074  ENSG00000267467  \
# 1921        13.746092         6.160153  ...         9.898479         0.092957
# 5936         7.836823         1.364553  ...         2.701847         0.637189
# 5931        28.537830         1.546921  ...        21.098441         0.000000
# 5928         3.709542         2.732352  ...         1.009128         0.000000
# 5926         7.939135         1.824480  ...         1.582215         0.000000
# ...               ...              ...  ...              ...              ...
# 4826         8.503381         0.994787  ...         1.324405         0.173291
# 4831         5.803060         1.778630  ...         2.024873         0.624021
# 8648         5.753635         1.211891  ...         3.216982         0.268924
# 2263         8.946199         1.480787  ...         4.060936         0.465955
# 2816         9.937944         1.562338  ...         3.737674         0.069003
#
#       ENSG00000269404  ENSG00000270999  ENSG00000271503  ENSG00000273749  \
# 1921         3.082746         0.000000        40.135650        41.826091
# 5936         0.778437         0.160316         9.836573        45.617194
# 5931         0.627473         0.000000         7.870030        66.468640
# 5928         0.594432         0.000000        20.859734        57.244140
# 5926         0.606945         0.000000        17.729025        63.327205
# ...               ...              ...              ...              ...
# 4826         7.536303         0.298645       100.529080        57.968099
# 4831         0.795011         0.648174        22.903493        44.155038
# 8648         0.861924         0.000000        15.121620        76.523070
# 2263         0.895588         0.196406        15.143496        64.205272
# 2816         8.000608         0.892366        46.112792        49.103766
#
#       ENSG00000274736  ENSG00000275385  ENSG00000276566  correct_prediction
# 1921         0.399227         1.928391          0.00000               False
# 5936         0.305265        12.951730          5.46751                True
# 5931         0.000000         2.625727          0.00000                True
# 5928         0.092686        11.306840          0.00000                True
# 5926         1.054340         0.000000          0.00000                True
# ...               ...              ...              ...                 ...
# 4826         0.657303        15.845610         26.59740               False
# 4831         0.183690         0.772245         15.32030               False
# 8648         0.084260         9.001380          0.00000               False
# 2263         2.138957        35.317700          0.00000               False
# 2816         2.344436        43.518500         22.05730               False
#
# [9002 rows x 827 columns]

# %%
df_sorted
# Out:
#      immune_subtype  ENSG00000000003  ENSG00000000938  ENSG00000002549  \
# 1921             C1        11.594583         4.406692        67.946749
# 5936             C1        90.922840         2.688882       110.052623
# 5931             C1        17.182080         0.554300        40.694352
# 5928             C1        39.801995         2.825573        54.177553
# 5926             C1        63.173188         4.577430        42.635002
# ...             ...              ...              ...              ...
# 4826             C6         3.706540        10.106416       158.210769
# 4831             C6        41.825828         2.552468       116.600487
# 8648             C6        25.487009         6.408825        48.545101
# 2263             C6        17.579842        18.383990        58.624171
# 2816             C6        20.272618         4.609404        63.443719
#
#       ENSG00000002726  ENSG00000002933  ENSG00000004468  ENSG00000005302  \
# 1921         0.465439        84.156429         0.760922        18.264237
# 5936        81.505346       483.355557         1.412301        20.683607
# 5931        18.391933        15.557973         0.225194         7.527834
# 5928         4.938320        39.437935         0.753132        12.103748
# 5926        46.455515        10.324238         5.759002        16.541371
# ...               ...              ...              ...              ...
# 4826         0.632195        51.345266        21.378058        31.268695
# 4831         0.214475        67.465646         1.279970        22.413583
# 8648         0.904519        77.909946         0.551660        26.351628
# 2263       110.464455       587.231955         1.007275        12.436026
# 2816       215.910697       159.230684         3.827641        18.939639
#
#       ENSG00000006062  ENSG00000006638  ...  ENSG00000266074  ENSG00000267467  \
# 1921        13.746092         6.160153  ...         9.898479         0.092957
# 5936         7.836823         1.364553  ...         2.701847         0.637189
# 5931        28.537830         1.546921  ...        21.098441         0.000000
# 5928         3.709542         2.732352  ...         1.009128         0.000000
# 5926         7.939135         1.824480  ...         1.582215         0.000000
# ...               ...              ...  ...              ...              ...
# 4826         8.503381         0.994787  ...         1.324405         0.173291
# 4831         5.803060         1.778630  ...         2.024873         0.624021
# 8648         5.753635         1.211891  ...         3.216982         0.268924
# 2263         8.946199         1.480787  ...         4.060936         0.465955
# 2816         9.937944         1.562338  ...         3.737674         0.069003
#
#       ENSG00000269404  ENSG00000270999  ENSG00000271503  ENSG00000273749  \
# 1921         3.082746         0.000000        40.135650        41.826091
# 5936         0.778437         0.160316         9.836573        45.617194
# 5931         0.627473         0.000000         7.870030        66.468640
# 5928         0.594432         0.000000        20.859734        57.244140
# 5926         0.606945         0.000000        17.729025        63.327205
# ...               ...              ...              ...              ...
# 4826         7.536303         0.298645       100.529080        57.968099
# 4831         0.795011         0.648174        22.903493        44.155038
# 8648         0.861924         0.000000        15.121620        76.523070
# 2263         0.895588         0.196406        15.143496        64.205272
# 2816         8.000608         0.892366        46.112792        49.103766
#
#       ENSG00000274736  ENSG00000275385  ENSG00000276566  correct_prediction
# 1921         0.399227         1.928391          0.00000               False
# 5936         0.305265        12.951730          5.46751                True
# 5931         0.000000         2.625727          0.00000                True
# 5928         0.092686        11.306840          0.00000                True
# 5926         1.054340         0.000000          0.00000                True
# ...               ...              ...              ...                 ...
# 4826         0.657303        15.845610         26.59740               False
# 4831         0.183690         0.772245         15.32030               False
# 8648         0.084260         9.001380          0.00000               False
# 2263         2.138957        35.317700          0.00000               False
# 2816         2.344436        43.518500         22.05730               False
#
# [9002 rows x 827 columns]

# %%
#isolates the signfigant values that will be reduced
#x = df_sorted.drop(['tcga_participant_barcode', 'immune_subtype'], axis=1)
x = df_sorted.drop(['immune_subtype', "correct_prediction"], axis=1)
#seperates the y-value and puts it aside for use later
y = df_sorted['correct_prediction']

# %%
#making the model
umap_model = umap.UMAP(n_components=2, random_state=11)
#running the x(values) throught to be reduced
embedding = umap_model.fit_transform(x)
#seeing reduced version
embedding
# Out:
# array([[8.017926  , 4.1361084 ],
#        [7.9422865 , 5.861159  ],
#        [9.526242  , 8.519604  ],
#        ...,
#        [6.682146  , 0.32770327],
#        [7.7729526 , 3.3525255 ],
#        [5.2072067 , 3.351073  ]], dtype=float32)

# %%
#setting plot size
plt.figure(figsize=(15, 10))
#setting color palate and having it change based on the unque y values
color_palette = sns.color_palette("Set1", n_colors=len(y.unique()))
color_mapping = {species: color for color, species in enumerate(y.unique())}
colors = [color_palette[color_mapping[species]] for species in y]
plt.scatter(embedding[:, 0], embedding[:, 1], c=colors, s=2)

# Adding a legend
legend_labels = y.unique()
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', label=label, markersize=15, markerfacecolor=color)
                  for label, color in zip(legend_labels, color_palette)]
plt.legend(handles=legend_handles, title="Immune Subtype")

plt.title('misclassfied points', fontsize=16)
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.show()

# %%
#setting plot size
plt.figure(figsize=(15, 10))

# Setting color palette and having it change based on the unique y values
color_palette = sns.color_palette("Set1", n_colors=len(y.unique()))
color_mapping = {species: color for color, species in enumerate(y.unique())}
colors = [color_palette[color_mapping[species]] for species in y]

# Scatter plot with custom colors based on unique values
plt.scatter(embedding[:, 0], embedding[:, 1], c=colors, s=2)

# Adding a legend with customized labels
legend_labels = ["Incorrect", "Correct"]  # Custom labels for True and False
legend_handles = [
    plt.Line2D([0], [0], marker='o', color='w', label=label, markersize=15, markerfacecolor=color)
    for label, color in zip(legend_labels, color_palette)
]

plt.legend(handles=legend_handles, title="Immune Subtype")

plt.title('Misclassified Points', fontsize=16)
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.show()

# %% [markdown]
# # Finding out how many of each we got wrong

# %%
misclassified_values = df_sorted[df_sorted['correct_prediction'] != True]

# %%
misclassified_values
# Out:
#      immune_subtype  ENSG00000000003  ENSG00000000938  ENSG00000002549  \
# 1921             C1        11.594583         4.406692        67.946749
# 5904             C1        48.796997         2.791814        77.922134
# 2279             C1        11.853537        23.556470       246.202681
# 2266             C1         8.477697        15.378510        80.043831
# 2235             C1        15.492053         3.907638        43.492125
# ...             ...              ...              ...              ...
# 4826             C6         3.706540        10.106416       158.210769
# 4831             C6        41.825828         2.552468       116.600487
# 8648             C6        25.487009         6.408825        48.545101
# 2263             C6        17.579842        18.383990        58.624171
# 2816             C6        20.272618         4.609404        63.443719
#
#       ENSG00000002726  ENSG00000002933  ENSG00000004468  ENSG00000005302  \
# 1921         0.465439        84.156429         0.760922        18.264237
# 5904         0.597166        17.652607         4.863240        27.888434
# 2279         3.133096       109.622637        12.854348        20.080413
# 2266         4.656138        65.368722        11.394050        15.349746
# 2235        71.333471       340.335690         2.528373        21.526471
# ...               ...              ...              ...              ...
# 4826         0.632195        51.345266        21.378058        31.268695
# 4831         0.214475        67.465646         1.279970        22.413583
# 8648         0.904519        77.909946         0.551660        26.351628
# 2263       110.464455       587.231955         1.007275        12.436026
# 2816       215.910697       159.230684         3.827641        18.939639
#
#       ENSG00000006062  ENSG00000006638  ...  ENSG00000266074  ENSG00000267467  \
# 1921        13.746092         6.160153  ...         9.898479         0.092957
# 5904         4.349115         0.827112  ...        10.610204         0.067920
# 2279        11.018988         1.650731  ...         6.512352         0.306780
# 2266         6.908746         1.268040  ...         4.445599         0.170514
# 2235        13.695313         1.629154  ...         4.850209         0.070641
# ...               ...              ...  ...              ...              ...
# 4826         8.503381         0.994787  ...         1.324405         0.173291
# 4831         5.803060         1.778630  ...         2.024873         0.624021
# 8648         5.753635         1.211891  ...         3.216982         0.268924
# 2263         8.946199         1.480787  ...         4.060936         0.465955
# 2816         9.937944         1.562338  ...         3.737674         0.069003
#
#       ENSG00000269404  ENSG00000270999  ENSG00000271503  ENSG00000273749  \
# 1921         3.082746         0.000000        40.135650        41.826091
# 5904         0.577429         0.000000        23.994794        74.132210
# 2279         3.033516         0.000000       260.473300        78.868003
# 2266         4.426973         0.000000        69.645900        52.915022
# 2235         4.977204         0.000000        45.757330        41.183135
# ...               ...              ...              ...              ...
# 4826         7.536303         0.298645       100.529080        57.968099
# 4831         0.795011         0.648174        22.903493        44.155038
# 8648         0.861924         0.000000        15.121620        76.523070
# 2263         0.895588         0.196406        15.143496        64.205272
# 2816         8.000608         0.892366        46.112792        49.103766
#
#       ENSG00000274736  ENSG00000275385  ENSG00000276566  correct_prediction
# 1921         0.399227         1.928391         0.000000               False
# 5904         0.197193        50.790100         0.232139               False
# 2279         2.458698       527.259000        16.998200               False
# 2266         3.623574       215.355900         5.541000               False
# 2235         0.870005        19.072900         0.000000               False
# ...               ...              ...              ...                 ...
# 4826         0.657303        15.845610        26.597400               False
# 4831         0.183690         0.772245        15.320300               False
# 8648         0.084260         9.001380         0.000000               False
# 2263         2.138957        35.317700         0.000000               False
# 2816         2.344436        43.518500        22.057300               False
#
# [1822 rows x 827 columns]

# %%
value_counts = misclassified_values['immune_subtype'].value_counts()

print(value_counts)
# Out:
# C4    479
# C3    394
# C1    385
# C2    339
# C6    177
# C5     48
# Name: immune_subtype, dtype: int64

# %%
479 + 394 + 385 +339 + 177 + 48
# Out:
# 1822

# %%
1822/9002
# Out:
# 0.20239946678515885

# %% [markdown]
# # Making the Kaplan Meier Plot ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
km_ds = pd.read_csv('tcga_days_to_death.tsv', delimiter='\t')
km_ds
# Out:
#          Unnamed: 0 vital_status  last_follow_up  days_to_death
# 0      TCGA-AG-A00C        Alive           183.0            NaN
# 1      TCGA-DY-A1DE        Alive          3932.0            NaN
# 2      TCGA-EI-6917        Alive           531.0            NaN
# 3      TCGA-DY-A0XA        Alive          3846.0            NaN
# 4      TCGA-AG-A01W        Alive             0.0            NaN
# ...             ...          ...             ...            ...
# 11162  TCGA-VQ-A8PD         Dead             NaN          496.0
# 11163  TCGA-MX-A5UJ        Alive           600.0            NaN
# 11164  TCGA-BR-6564         Dead            25.0          794.0
# 11165  TCGA-BR-4191         Dead             0.0          558.0
# 11166  TCGA-BR-6707         Dead           491.0          605.0
#
# [11167 rows x 4 columns]

# %%
km_df=pd.merge(km_ds, df, left_on='Unnamed: 0', right_on='tcga_participant_barcode', how='inner')
km_df = km_df.drop(columns=['Unnamed: 0'],axis=1)
km_df
# Out:
#      vital_status  last_follow_up  days_to_death tcga_participant_barcode  \
# 0           Alive           183.0            NaN             TCGA-AG-A00C
# 1           Alive          3932.0            NaN             TCGA-DY-A1DE
# 2           Alive           531.0            NaN             TCGA-EI-6917
# 3           Alive          3846.0            NaN             TCGA-DY-A0XA
# 4           Alive             0.0            NaN             TCGA-AG-A01W
# ...           ...             ...            ...                      ...
# 8975         Dead             NaN          496.0             TCGA-VQ-A8PD
# 8976        Alive           600.0            NaN             TCGA-MX-A5UJ
# 8977         Dead            25.0          794.0             TCGA-BR-6564
# 8978         Dead             0.0          558.0             TCGA-BR-4191
# 8979         Dead           491.0          605.0             TCGA-BR-6707
#
#      immune_subtype  ENSG00000000003  ENSG00000000938  ENSG00000002549  \
# 0                C1       101.059923         0.743907        50.028904
# 1                C2        85.974465         3.376868        79.330918
# 2                C2        36.913733        16.872247       127.246808
# 3                C1       139.394730         1.173850        43.763763
# 4                C2       125.349748         1.623721        77.420243
# ...             ...              ...              ...              ...
# 8975             C6        12.819064        10.254870        88.777513
# 8976             C2        22.607103         2.205309        83.747523
# 8977             C2         2.873285         1.309684        39.512099
# 8978             C2        63.219980         8.709484        91.951096
# 8979             C2        62.075452         2.481380        53.374517
#
#       ENSG00000002726  ENSG00000002933  ...  ENSG00000265972  ENSG00000266074  \
# 0           83.382350       173.981564  ...       145.406350         0.560705
# 1           59.197166       263.984183  ...       166.477055         4.099854
# 2            2.279281        63.893499  ...       165.488560         4.006222
# 3           35.680645       220.108655  ...       114.543006         3.146026
# 4           64.624579       132.862677  ...        81.202005         0.745667
# ...               ...              ...  ...              ...              ...
# 8975        73.927260       107.431224  ...       424.846700         4.878343
# 8976       125.629626       172.059724  ...       130.547210         4.919111
# 8977        13.634084        54.408307  ...       136.849050         4.073690
# 8978        20.269530       175.324608  ...       191.499660         1.275994
# 8979         4.561022        28.680587  ...        47.601695         0.659856
#
#       ENSG00000267467  ENSG00000269404  ENSG00000270999  ENSG00000271503  \
# 0            0.610468         1.311974         0.000000         8.138839
# 1            0.446600         0.728892         0.000000        15.372278
# 2            0.419040         1.867048         0.000000        41.439120
# 3            0.139431         0.670389         0.268606         9.193690
# 4            0.000000         2.045478         0.000000        26.508600
# ...               ...              ...              ...              ...
# 8975         0.889289         9.168937         0.000000        64.784650
# 8976         0.000000         4.768798         0.000000        12.359134
# 8977         0.118451         1.552021         0.000000        20.850768
# 8978         1.096618         3.224097         3.671290        63.136480
# 8979         0.089704         1.308411         0.078086        91.395220
#
#       ENSG00000273749  ENSG00000274736  ENSG00000275385  ENSG00000276566
# 0           52.689503         0.000000         0.000000         0.000000
# 1           35.591649         0.187882        21.164840         2.981990
# 2           74.777981         1.071329        66.944800         1.347520
# 3           44.273660         0.000000         2.648580         0.542517
# 4           82.979664         0.416056        27.315950         0.000000
# ...               ...              ...              ...              ...
# 8975        58.018390         0.488248         5.272119         6.634770
# 8976        37.590533         2.001120        27.883950       262.893000
# 8977        15.882302         0.397331         0.157075         2.385840
# 8978        53.714069         1.275257        60.263500         4.565630
# 8979        13.360290         0.086488        76.245100         0.439394
#
# [8980 rows x 830 columns]

# %%
km_df['vital_status'].unique()
# Out:
# array(['Alive', 'Dead', 'Not Reported'], dtype=object)

# %%
#example

print(km_df.shape[0])
len(set(km_df['tcga_participant_barcode'].unique()))
# Out:
# 8980
# 8980

# %%
km_df
# Out:
#      vital_status  last_follow_up  days_to_death tcga_participant_barcode  \
# 0           Alive           183.0            NaN             TCGA-AG-A00C
# 1           Alive          3932.0            NaN             TCGA-DY-A1DE
# 2           Alive           531.0            NaN             TCGA-EI-6917
# 3           Alive          3846.0            NaN             TCGA-DY-A0XA
# 4           Alive             0.0            NaN             TCGA-AG-A01W
# ...           ...             ...            ...                      ...
# 8975         Dead             NaN          496.0             TCGA-VQ-A8PD
# 8976        Alive           600.0            NaN             TCGA-MX-A5UJ
# 8977         Dead            25.0          794.0             TCGA-BR-6564
# 8978         Dead             0.0          558.0             TCGA-BR-4191
# 8979         Dead           491.0          605.0             TCGA-BR-6707
#
#      immune_subtype  ENSG00000000003  ENSG00000000938  ENSG00000002549  \
# 0                C1       101.059923         0.743907        50.028904
# 1                C2        85.974465         3.376868        79.330918
# 2                C2        36.913733        16.872247       127.246808
# 3                C1       139.394730         1.173850        43.763763
# 4                C2       125.349748         1.623721        77.420243
# ...             ...              ...              ...              ...
# 8975             C6        12.819064        10.254870        88.777513
# 8976             C2        22.607103         2.205309        83.747523
# 8977             C2         2.873285         1.309684        39.512099
# 8978             C2        63.219980         8.709484        91.951096
# 8979             C2        62.075452         2.481380        53.374517
#
#       ENSG00000002726  ENSG00000002933  ...  ENSG00000265972  ENSG00000266074  \
# 0           83.382350       173.981564  ...       145.406350         0.560705
# 1           59.197166       263.984183  ...       166.477055         4.099854
# 2            2.279281        63.893499  ...       165.488560         4.006222
# 3           35.680645       220.108655  ...       114.543006         3.146026
# 4           64.624579       132.862677  ...        81.202005         0.745667
# ...               ...              ...  ...              ...              ...
# 8975        73.927260       107.431224  ...       424.846700         4.878343
# 8976       125.629626       172.059724  ...       130.547210         4.919111
# 8977        13.634084        54.408307  ...       136.849050         4.073690
# 8978        20.269530       175.324608  ...       191.499660         1.275994
# 8979         4.561022        28.680587  ...        47.601695         0.659856
#
#       ENSG00000267467  ENSG00000269404  ENSG00000270999  ENSG00000271503  \
# 0            0.610468         1.311974         0.000000         8.138839
# 1            0.446600         0.728892         0.000000        15.372278
# 2            0.419040         1.867048         0.000000        41.439120
# 3            0.139431         0.670389         0.268606         9.193690
# 4            0.000000         2.045478         0.000000        26.508600
# ...               ...              ...              ...              ...
# 8975         0.889289         9.168937         0.000000        64.784650
# 8976         0.000000         4.768798         0.000000        12.359134
# 8977         0.118451         1.552021         0.000000        20.850768
# 8978         1.096618         3.224097         3.671290        63.136480
# 8979         0.089704         1.308411         0.078086        91.395220
#
#       ENSG00000273749  ENSG00000274736  ENSG00000275385  ENSG00000276566
# 0           52.689503         0.000000         0.000000         0.000000
# 1           35.591649         0.187882        21.164840         2.981990
# 2           74.777981         1.071329        66.944800         1.347520
# 3           44.273660         0.000000         2.648580         0.542517
# 4           82.979664         0.416056        27.315950         0.000000
# ...               ...              ...              ...              ...
# 8975        58.018390         0.488248         5.272119         6.634770
# 8976        37.590533         2.001120        27.883950       262.893000
# 8977        15.882302         0.397331         0.157075         2.385840
# 8978        53.714069         1.275257        60.263500         4.565630
# 8979        13.360290         0.086488        76.245100         0.439394
#
# [8980 rows x 830 columns]

# %%
km_df2 = km_df.dropna(subset=['days_to_death'])
km_df2
# Out:
#      vital_status  last_follow_up  days_to_death tcga_participant_barcode  \
# 20           Dead             0.0          303.0             TCGA-F5-6464
# 25           Dead            21.0         1314.0             TCGA-AH-6643
# 33           Dead           452.0          869.0             TCGA-F5-6702
# 36           Dead            23.0          361.0             TCGA-F5-6863
# 44           Dead            31.0         1096.0             TCGA-AG-3582
# ...           ...             ...            ...                      ...
# 8971         Dead             NaN          281.0             TCGA-R5-A805
# 8975         Dead             NaN          496.0             TCGA-VQ-A8PD
# 8977         Dead            25.0          794.0             TCGA-BR-6564
# 8978         Dead             0.0          558.0             TCGA-BR-4191
# 8979         Dead           491.0          605.0             TCGA-BR-6707
#
#      immune_subtype  ENSG00000000003  ENSG00000000938  ENSG00000002549  \
# 20               C1        22.369909         8.489547       118.079762
# 25               C1        65.319700         2.841025        37.487143
# 33               C1       135.237640         5.132837        56.197460
# 36               C1       104.096440         0.878339        50.621007
# 44               C1       219.336782         3.887703        50.549402
# ...             ...              ...              ...              ...
# 8971             C2        12.631167        13.748817        48.295470
# 8975             C6        12.819064        10.254870        88.777513
# 8977             C2         2.873285         1.309684        39.512099
# 8978             C2        63.219980         8.709484        91.951096
# 8979             C2        62.075452         2.481380        53.374517
#
#       ENSG00000002726  ENSG00000002933  ...  ENSG00000265972  ENSG00000266074  \
# 20          59.797677        68.669178  ...       486.577621         4.317063
# 25          84.539769       445.685264  ...       455.528220         1.770381
# 33         165.389042       353.890990  ...       312.251810         2.811334
# 36         113.828891       529.051020  ...       168.133453         5.149245
# 44         107.554910       370.710706  ...       134.964740         4.421731
# ...               ...              ...  ...              ...              ...
# 8971       105.012763       117.378837  ...        89.573652         2.052962
# 8975        73.927260       107.431224  ...       424.846700         4.878343
# 8977        13.634084        54.408307  ...       136.849050         4.073690
# 8978        20.269530       175.324608  ...       191.499660         1.275994
# 8979         4.561022        28.680587  ...        47.601695         0.659856
#
#       ENSG00000267467  ENSG00000269404  ENSG00000270999  ENSG00000271503  \
# 20           0.141556         2.363292         0.000000        45.625610
# 25           0.330753         0.526805         1.203460         5.385347
# 33           0.242215         0.878868         0.129107        15.752680
# 36           0.261750         0.524302         0.000000         6.119440
# 44           0.000000         0.389253         0.000000         8.820840
# ...               ...              ...              ...              ...
# 8971         0.195859        51.602854         0.297726        24.439940
# 8975         0.889289         9.168937         0.000000        64.784650
# 8977         0.118451         1.552021         0.000000        20.850768
# 8978         1.096618         3.224097         3.671290        63.136480
# 8979         0.089704         1.308411         0.078086        91.395220
#
#       ENSG00000273749  ENSG00000274736  ENSG00000275385  ENSG00000276566
# 20          77.402087         0.396210        80.116900         0.461065
# 25          36.800696         0.225975         2.110487         0.000000
# 33          52.158878         1.261950        93.383000        18.212300
# 36          52.287536         0.090002         2.172525         0.000000
# 44          51.681057         0.000000        18.040750         0.367395
# ...               ...              ...              ...              ...
# 8971        35.034293         6.788706       246.898600         0.065677
# 8975        58.018390         0.488248         5.272119         6.634770
# 8977        15.882302         0.397331         0.157075         2.385840
# 8978        53.714069         1.275257        60.263500         4.565630
# 8979        13.360290         0.086488        76.245100         0.439394
#
# [2515 rows x 830 columns]

# %%
km_df2
# Out:
#      vital_status  last_follow_up  days_to_death tcga_participant_barcode  \
# 20           Dead             0.0          303.0             TCGA-F5-6464
# 25           Dead            21.0         1314.0             TCGA-AH-6643
# 33           Dead           452.0          869.0             TCGA-F5-6702
# 36           Dead            23.0          361.0             TCGA-F5-6863
# 44           Dead            31.0         1096.0             TCGA-AG-3582
# ...           ...             ...            ...                      ...
# 8971         Dead             NaN          281.0             TCGA-R5-A805
# 8975         Dead             NaN          496.0             TCGA-VQ-A8PD
# 8977         Dead            25.0          794.0             TCGA-BR-6564
# 8978         Dead             0.0          558.0             TCGA-BR-4191
# 8979         Dead           491.0          605.0             TCGA-BR-6707
#
#      immune_subtype  ENSG00000000003  ENSG00000000938  ENSG00000002549  \
# 20               C1        22.369909         8.489547       118.079762
# 25               C1        65.319700         2.841025        37.487143
# 33               C1       135.237640         5.132837        56.197460
# 36               C1       104.096440         0.878339        50.621007
# 44               C1       219.336782         3.887703        50.549402
# ...             ...              ...              ...              ...
# 8971             C2        12.631167        13.748817        48.295470
# 8975             C6        12.819064        10.254870        88.777513
# 8977             C2         2.873285         1.309684        39.512099
# 8978             C2        63.219980         8.709484        91.951096
# 8979             C2        62.075452         2.481380        53.374517
#
#       ENSG00000002726  ENSG00000002933  ...  ENSG00000265972  ENSG00000266074  \
# 20          59.797677        68.669178  ...       486.577621         4.317063
# 25          84.539769       445.685264  ...       455.528220         1.770381
# 33         165.389042       353.890990  ...       312.251810         2.811334
# 36         113.828891       529.051020  ...       168.133453         5.149245
# 44         107.554910       370.710706  ...       134.964740         4.421731
# ...               ...              ...  ...              ...              ...
# 8971       105.012763       117.378837  ...        89.573652         2.052962
# 8975        73.927260       107.431224  ...       424.846700         4.878343
# 8977        13.634084        54.408307  ...       136.849050         4.073690
# 8978        20.269530       175.324608  ...       191.499660         1.275994
# 8979         4.561022        28.680587  ...        47.601695         0.659856
#
#       ENSG00000267467  ENSG00000269404  ENSG00000270999  ENSG00000271503  \
# 20           0.141556         2.363292         0.000000        45.625610
# 25           0.330753         0.526805         1.203460         5.385347
# 33           0.242215         0.878868         0.129107        15.752680
# 36           0.261750         0.524302         0.000000         6.119440
# 44           0.000000         0.389253         0.000000         8.820840
# ...               ...              ...              ...              ...
# 8971         0.195859        51.602854         0.297726        24.439940
# 8975         0.889289         9.168937         0.000000        64.784650
# 8977         0.118451         1.552021         0.000000        20.850768
# 8978         1.096618         3.224097         3.671290        63.136480
# 8979         0.089704         1.308411         0.078086        91.395220
#
#       ENSG00000273749  ENSG00000274736  ENSG00000275385  ENSG00000276566
# 20          77.402087         0.396210        80.116900         0.461065
# 25          36.800696         0.225975         2.110487         0.000000
# 33          52.158878         1.261950        93.383000        18.212300
# 36          52.287536         0.090002         2.172525         0.000000
# 44          51.681057         0.000000        18.040750         0.367395
# ...               ...              ...              ...              ...
# 8971        35.034293         6.788706       246.898600         0.065677
# 8975        58.018390         0.488248         5.272119         6.634770
# 8977        15.882302         0.397331         0.157075         2.385840
# 8978        53.714069         1.275257        60.263500         4.565630
# 8979        13.360290         0.086488        76.245100         0.439394
#
# [2515 rows x 830 columns]

# %%
km_df2['vital_status'].replace('Dead', 1.0)
# Out:
# 20      1.0
# 25      1.0
# 33      1.0
# 36      1.0
# 44      1.0
#        ...
# 8971    1.0
# 8975    1.0
# 8977    1.0
# 8978    1.0
# 8979    1.0
# Name: vital_status, Length: 2515, dtype: float64

# %%
km_df2['vital_status_binary'] = km_df2['vital_status'].replace('Dead', 1.0)

km_df2.head()
# Out:
# /var/folders/f2/s93pnt0d3hxdjkhfxs6gb1l1rb54ft/T/ipykernel_20057/1417973569.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   km_df2['vital_status_binary'] = km_df2['vital_status'].replace('Dead', 1.0)
#    vital_status  last_follow_up  days_to_death tcga_participant_barcode  \
# 20         Dead             0.0          303.0             TCGA-F5-6464
# 25         Dead            21.0         1314.0             TCGA-AH-6643
# 33         Dead           452.0          869.0             TCGA-F5-6702
# 36         Dead            23.0          361.0             TCGA-F5-6863
# 44         Dead            31.0         1096.0             TCGA-AG-3582
#
#    immune_subtype  ENSG00000000003  ENSG00000000938  ENSG00000002549  \
# 20             C1        22.369909         8.489547       118.079762
# 25             C1        65.319700         2.841025        37.487143
# 33             C1       135.237640         5.132837        56.197460
# 36             C1       104.096440         0.878339        50.621007
# 44             C1       219.336782         3.887703        50.549402
#
#     ENSG00000002726  ENSG00000002933  ...  ENSG00000266074  ENSG00000267467  \
# 20        59.797677        68.669178  ...         4.317063         0.141556
# 25        84.539769       445.685264  ...         1.770381         0.330753
# 33       165.389042       353.890990  ...         2.811334         0.242215
# 36       113.828891       529.051020  ...         5.149245         0.261750
# 44       107.554910       370.710706  ...         4.421731         0.000000
#
#     ENSG00000269404  ENSG00000270999  ENSG00000271503  ENSG00000273749  \
# 20         2.363292         0.000000        45.625610        77.402087
# 25         0.526805         1.203460         5.385347        36.800696
# 33         0.878868         0.129107        15.752680        52.158878
# 36         0.524302         0.000000         6.119440        52.287536
# 44         0.389253         0.000000         8.820840        51.681057
#
#     ENSG00000274736  ENSG00000275385  ENSG00000276566  vital_status_binary
# 20         0.396210        80.116900         0.461065                  1.0
# 25         0.225975         2.110487         0.000000                  1.0
# 33         1.261950        93.383000        18.212300                  1.0
# 36         0.090002         2.172525         0.000000                  1.0
# 44         0.000000        18.040750         0.367395                  1.0
#
# [5 rows x 831 columns]

# %%
km_df2['immune_subtype'].unique()
# Out:
# array(['C1', 'C3', 'C2', 'C4', 'C6', 'C5'], dtype=object)

# %%
kmf = KaplanMeierFitter()

# %%
kmf1= KaplanMeierFitter()
kmf2= KaplanMeierFitter()
kmf3= KaplanMeierFitter()
kmf4= KaplanMeierFitter()
kmf5= KaplanMeierFitter()
kmf6= KaplanMeierFitter()

# %%
C1 = km_df2[km_df2['immune_subtype']=='C1']
C2 = km_df2[km_df2['immune_subtype']=='C2']
C3 = km_df2[km_df2['immune_subtype']=='C3']
C4 = km_df2[km_df2['immune_subtype']=='C4']
C5 = km_df2[km_df2['immune_subtype']=='C5']
C6 = km_df2[km_df2['immune_subtype']=='C6']

# %%
C1
# Out:
#      vital_status  last_follow_up  days_to_death tcga_participant_barcode  \
# 20           Dead             0.0          303.0             TCGA-F5-6464
# 25           Dead            21.0         1314.0             TCGA-AH-6643
# 33           Dead           452.0          869.0             TCGA-F5-6702
# 36           Dead            23.0          361.0             TCGA-F5-6863
# 44           Dead            31.0         1096.0             TCGA-AG-3582
# ...           ...             ...            ...                      ...
# 8951         Dead             NaN          491.0             TCGA-VQ-AA6I
# 8959         Dead             NaN          562.0             TCGA-VQ-A8E0
# 8961         Dead           820.0          832.0             TCGA-VQ-A8PU
# 8969         Dead            24.0          273.0             TCGA-BR-A4IZ
# 8970         Dead             NaN          426.0             TCGA-CG-4441
#
#      immune_subtype  ENSG00000000003  ENSG00000000938  ENSG00000002549  \
# 20               C1        22.369909         8.489547       118.079762
# 25               C1        65.319700         2.841025        37.487143
# 33               C1       135.237640         5.132837        56.197460
# 36               C1       104.096440         0.878339        50.621007
# 44               C1       219.336782         3.887703        50.549402
# ...             ...              ...              ...              ...
# 8951             C1         8.119302         2.488953        80.043722
# 8959             C1        11.694873         5.762591        54.864950
# 8961             C1         8.652902         1.090504        57.104498
# 8969             C1        13.952444         6.887970        70.294437
# 8970             C1         9.664282         8.562990        55.481016
#
#       ENSG00000002726  ENSG00000002933  ...  ENSG00000266074  ENSG00000267467  \
# 20          59.797677        68.669178  ...         4.317063         0.141556
# 25          84.539769       445.685264  ...         1.770381         0.330753
# 33         165.389042       353.890990  ...         2.811334         0.242215
# 36         113.828891       529.051020  ...         5.149245         0.261750
# 44         107.554910       370.710706  ...         4.421731         0.000000
# ...               ...              ...  ...              ...              ...
# 8951        30.550431        41.918864  ...         2.408966         0.223595
# 8959        27.110362       136.786401  ...         8.777465         0.294958
# 8961       173.102834       518.082295  ...         6.553138         0.237851
# 8969        12.224433       183.585844  ...         7.506633         0.266610
# 8970        95.521550       174.874164  ...         3.823824         0.265900
#
#       ENSG00000269404  ENSG00000270999  ENSG00000271503  ENSG00000273749  \
# 20           2.363292         0.000000        45.625610        77.402087
# 25           0.526805         1.203460         5.385347        36.800696
# 33           0.878868         0.129107        15.752680        52.158878
# 36           0.524302         0.000000         6.119440        52.287536
# 44           0.389253         0.000000         8.820840        51.681057
# ...               ...              ...              ...              ...
# 8951         1.233902         0.738417        25.656321        63.864816
# 8959         2.810255         0.000000         9.684993        98.891927
# 8961         0.576378         0.000000         7.297779        80.454824
# 8969        12.044130         0.000000        48.877790        43.252205
# 8970         2.950780         3.859640        14.199260        44.620721
#
#       ENSG00000274736  ENSG00000275385  ENSG00000276566  vital_status_binary
# 20           0.396210        80.116900         0.461065                  1.0
# 25           0.225975         2.110487         0.000000                  1.0
# 33           1.261950        93.383000        18.212300                  1.0
# 36           0.090002         2.172525         0.000000                  1.0
# 44           0.000000        18.040750         0.367395                  1.0
# ...               ...              ...              ...                  ...
# 8951         0.203107        12.319040         0.000000                  1.0
# 8959         0.768189        38.771220         0.000000                  1.0
# 8961         0.063347         1.491245         0.257043                  1.0
# 8969         2.678053        66.913770         0.809267                  1.0
# 8970         0.459481        36.930400        11.901100                  1.0
#
# [730 rows x 831 columns]

# %%
kmf1.fit(durations = C1['days_to_death'], event_observed = C1['vital_status_binary'], label = 'C1')
kmf2.fit(durations = C2['days_to_death'], event_observed = C2['vital_status_binary'], label = 'C2')
kmf3.fit(durations = C3['days_to_death'], event_observed = C3['vital_status_binary'], label = 'C3')
kmf4.fit(durations = C4['days_to_death'], event_observed = C4['vital_status_binary'], label = 'C4')
kmf5.fit(durations = C5['days_to_death'], event_observed = C5['vital_status_binary'], label = 'C5')
kmf6.fit(durations = C6['days_to_death'], event_observed = C6['vital_status_binary'], label = 'C6')
# Out:
# <lifelines.KaplanMeierFitter:"C6", fitted with 73 total observations, 0 right-censored observations>

# %%
kmf1.event_table
# Out:
#           removed  observed  censored  entrance  at_risk
# event_at
# 0.0             9         9         0       730      730
# 1.0             2         2         0         0      721
# 3.0             1         1         0         0      719
# 5.0             2         2         0         0      718
# 6.0             1         1         0         0      716
# ...           ...       ...       ...       ...      ...
# 3924.0          1         1         0         0        5
# 3941.0          1         1         0         0        4
# 4624.0          1         1         0         0        3
# 6593.0          1         1         0         0        2
# 6972.0          1         1         0         0        1
#
# [570 rows x 5 columns]

# %%
kmf1.predict(10)
# Out:
# 0.9753424657534246

# %%
kmf4.predict(10)
# Out:
# 0.9855421686746996

# %%
kmf1.survival_function_
# Out:
#                 C1
# timeline
# 0.0       0.987671
# 1.0       0.984932
# 3.0       0.983562
# 5.0       0.980822
# 6.0       0.979452
# ...            ...
# 3924.0    0.005479
# 3941.0    0.004110
# 4624.0    0.002740
# 6593.0    0.001370
# 6972.0    0.000000
#
# [570 rows x 1 columns]

# %%
plt.figure(figsize=(15, 10))

kmf1.plot()
kmf2.plot()
kmf3.plot()
kmf4.plot()
kmf5.plot()
kmf6.plot()

sns.set_palette("tab10")

plt.xlabel('Days Passed')
plt.ylabel('Survival %')
plt.title('Immune Subtype Significance')
# Out:
# Text(0.5, 1.0, 'Immune Subtype Significance')

# %% [raw]
# Caux porportianl hazard,
# shows that there is a signfigance in classfiying immune subtypes
# if just done randobly it would all overlap
# shows that its not random

# %%
plt.figure(figsize=(10, 6))

# Get unique group labels
unique_groups = km_df2['immune_subtype'].unique()

# Loop through each group and fit Kaplan-Meier
for group in unique_groups:
    subset_data = km_df2[km_df2['immune_subtype'] == group]
    kmf.fit(subset_data['days_to_death'], event_observed=subset_data['vital_status_binary'])
    kmf.plot(label=group)

# Customize the plot
plt.title('Kaplan-Meier Survival Curve')
plt.xlabel('Days To Death')
plt.ylabel('Survival Probability')
plt.legend()

# Show the plot
plt.show()
